# %%
import sys
import os
from pathlib import Path
import pandas as pd

# %%
# Set the path to the project root directory
# and add the src directory to the Python path
project_root = os.path.abspath("..")
src_path = os.path.join(project_root, "src")
if src_path not in sys.path:
    sys.path.append(src_path)

from utils import load_excel_files

# %%
# Definir rutas
raw_path = "C:/Allianz/prueba_allianz/data/raw"
output_path = "C:/Allianz/prueba_allianz/data/processed"
parquet_file = os.path.join(output_path, "allianz_consolidado.parquet")
csv_file = os.path.join(output_path, "allianz_consolidado.csv")

# %%
# Consolidar archivos excel en un solo dataframe
df_all = load_excel_files(raw_path)
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2087581 entries, 0 to 2087580
# Data columns (total 32 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   fecha_registro             object
#  1   comparison_id              object
#  2   fecha_nacimiento           object
#  3   edad                       object
#  4   ocupacion                  object
#  5   tipo_identificacion        object
#  6   genero                     object
#  7   fasecolda_id               object
#  8   marca                      object
#  9   clase                      object
#  10  referencia_vehiculo        object
#  11  vehiculo_uso               object
#  12  tipo_caja                  object
#  13  valor_fasecolda            object
#  14  modelo                     object
#  15  dane_id                    object
#  16  ciudad                     object
#  17  departamento_id            object
#  18  departamento               object
# ...

# %%
df_all.head()
# Out:
#              fecha_registro                     comparison_id  \
# 0  2024-10-29T22:22:50.773Z  e515ea0cbd2c6235f9c1bcca3f1182b2
# 1  2024-10-29T22:22:50.773Z  e515ea0cbd2c6235f9c1bcca3f1182b2
# 2  2024-10-29T22:22:50.773Z  e515ea0cbd2c6235f9c1bcca3f1182b2
# 3  2024-10-29T22:22:50.773Z  e515ea0cbd2c6235f9c1bcca3f1182b2
# 4  2024-10-16T13:09:37.634Z  eba50136d23a42cf47f7701da546e68d
#
#   fecha_nacimiento edad   ocupacion tipo_identificacion    genero  \
# 0       1965-01-01   59  Estudiante                  CC  Femenino
# 1       1965-01-01   59  Estudiante                  CC  Femenino
# 2       1965-01-01   59  Estudiante                  CC  Femenino
# 3       1965-01-01   59  Estudiante                  CC  Femenino
# 4       1995-01-04   29    Empleado                  CC  Femenino
#
#   fasecolda_id      marca             clase  ...  \
# 0     00606066       AUDI  CAMIONETA PASAJ.  ...
# 1     00606066       AUDI  CAMIONETA PASAJ.  ...
# ...

# %%
df_all.tail()
# Out:
#                    fecha_registro                     comparison_id  \
# 2087576  2025-01-28T01:07:51.221Z  b0683e81467db96195277834254937db
# 2087577  2025-01-28T01:07:51.221Z  b0683e81467db96195277834254937db
# 2087578  2025-01-28T01:07:51.221Z  b0683e81467db96195277834254937db
# 2087579  2025-01-28T01:07:51.221Z  b0683e81467db96195277834254937db
# 2087580  2025-01-28T01:07:51.221Z  b0683e81467db96195277834254937db
#
#         fecha_nacimiento edad   ocupacion tipo_identificacion     genero  \
# 2087576       1959-06-21   65  Estudiante                  CC  Masculino
# 2087577       1959-06-21   65  Estudiante                  CC  Masculino
# 2087578       1959-06-21   65  Estudiante                  CC  Masculino
# 2087579       1959-06-21   65  Estudiante                  CC  Masculino
# 2087580       1959-06-21   65  Estudiante                  CC  Masculino
#
#         fasecolda_id      marca      clase  ...  \
# 2087576     01601146  CHEVROLET  AUTOMOVIL  ...
# ...

# %%
# Guardar el archivo consolidado en formato csv
df_all.to_csv(csv_file, index=False, sep=";", encoding="utf-8-sig")
print(f"✅ Guardado en formato CSV: {csv_file}")
# Out:
# ✅ Guardado en formato CSV: C:/Allianz/prueba_allianz/data/processed\allianz_consolidado.csv
